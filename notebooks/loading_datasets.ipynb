# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd

import time

import sys
sys.path.append("../")  
from src.data_collection import enrich_film, get_movie_details, get_movie_keywords
# in order to use these modules, I'm using an API_KEY. If you try to rerun the code, it'll fail if you don't add your API_KEY

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# We have several datasets, we'll load all of them here. We'll see what each one of them have,

# %% [markdown]
# ### MovieLens

# %% [markdown]
# MovieLens will be our base. There are two reasons for this:
# - It has the links dataset which will be the core of our future database in SQL
# - They are the cleanest and clearest datasets
# - It only has movies. IMBD includes some TVshows and other stuff, not only movies.
#
# It has almost 90.000 records which will make also all our datasets more manageable

# %%
links = pd.read_csv("../data/raw/movielens/links.csv")
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
links.shape
# Out:
# (86537, 3)

# %%
movies = pd.read_csv("../data/raw/movielens/movies.csv")
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.shape
# Out:
# (86537, 3)

# %%
ratings = pd.read_csv("../data/raw/movielens/ratings.csv")
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        1     4.0  1225734739
# 1       1      110     4.0  1225865086
# 2       1      158     4.0  1225733503
# 3       1      260     4.5  1225735204
# 4       1      356     5.0  1225735119

# %%
ratings.shape
# Out:
# (33832162, 4)

# %% [markdown]
# I'm loading now some datasets that may not be useful for analysis, but could help a lot with ML.

# %%
tags = pd.read_csv("../data/raw/movielens/tags.csv")
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      10      260   good vs evil  1430666558
# 1      10      260  Harrison Ford  1430666505
# 2      10      260         sci-fi  1430666538
# 3      14     1221      Al Pacino  1311600756
# 4      14     1221          mafia  1311600746

# %%
tags.shape
# Out:
# (2328315, 4)

# %%
genome_tags = pd.read_csv("../data/raw/movielens/genome-tags.csv")
genome_tags.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
genome_tags.shape
# Out:
# (1128, 2)

# %%
genome_scores = pd.read_csv("../data/raw/movielens/genome-scores.csv")
genome_scores.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.03200
# 1        1      2    0.02225
# 2        1      3    0.07000
# 3        1      4    0.05900
# 4        1      5    0.12300

# %%
genome_scores.shape
# Out:
# (18472128, 3)

# %% [markdown]
# ### IMDB

# %% [markdown]
# These datasets have a lot of information and require a lot of cleaning and decision making on several areas. However, we'll do that on the cleaning part. We'll just load them here.

# %%
name_basics = pd.read_csv("../data/raw/imbd/name.basics.tsv", sep='\t')
name_basics.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934      2025
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                    primaryProfession                           knownForTitles
# 0       actor,miscellaneous,producer  tt0072308,tt0050419,tt0027125,tt0025164
# 1   actress,miscellaneous,soundtrack  tt0037382,tt0075213,tt0038355,tt0045891
# 2  actress,music_department,producer  tt0057345,tt0049189,tt0056404,tt0054452
# 3      actor,writer,music_department  tt0072562,tt0077975,tt0080455,tt0078723
# 4              writer,director,actor  tt0050986,tt0069467,tt0050976,tt0083922

# %%
name_basics.shape
# Out:
# (15336275, 6)

# %%
title_basics = pd.read_csv("../data/raw/imbd/title.basics.tsv", sep='\t')
title_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              5  Animation,Comedy,Romance
# 3        0      1892      \N             12           Animation,Short
# 4        0      1893      \N              1                     Short

# %%
title_basics.shape
# Out:
# (12508399, 9)

# %%
title_crew = pd.read_csv("../data/raw/imbd/title.crew.tsv", sep='\t')
title_crew.head()
# Out:
#       tconst  directors    writers
# 0  tt0000001  nm0005690         \N
# 1  tt0000002  nm0721526         \N
# 2  tt0000003  nm0721526  nm0721526
# 3  tt0000004  nm0721526         \N
# 4  tt0000005  nm0005690         \N

# %%
title_crew.shape
# Out:
# (12508399, 3)

# %%
title_ratings = pd.read_csv("../data/raw/imbd/title.ratings.tsv", sep='\t')
title_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2216
# 1  tt0000002            5.5       318
# 2  tt0000003            6.4      2334
# 3  tt0000004            5.1       199
# 4  tt0000005            6.2      3052

# %%
title_ratings.shape
# Out:
# (1670967, 3)

# %% [markdown]
# ### Kaggle

# %% [markdown]
# The original idea was to use the Bechdel API, but it had been discontinued.
#
# So, even though, this is a clear limitation it is still a good option in order to include a gender perspective.

# %%
bechdel = pd.read_csv("../data/external/bechdel_detailed.csv", index_col = 'Unnamed: 0')
bechdel.head()
# Out:
#                         title    year  rating  dubious      imdbid      id  \
# 0            Passage de Venus  1874.0     0.0      0.0   3155794.0  9602.0
# 1           La Rosace Magique  1877.0     0.0      0.0  14495706.0  9804.0
# 2  Sallie Gardner at a Gallop  1878.0     0.0      0.0   2221420.0  9603.0
# 3           Le singe musicien  1878.0     0.0      0.0  12592084.0  9806.0
# 4     Athlete Swinging a Pick  1881.0     0.0      0.0   7816420.0  9816.0
#
#    submitterid                 date  visible
# 0      18880.0  2021-04-02 20:58:09      1.0
# 1      19145.0  2021-05-11 00:11:22      1.0
# 2      18882.0  2021-04-03 02:25:27      1.0
# 3      19151.0  2021-05-11 23:38:54      1.0
# 4      19162.0  2021-05-13 01:32:14      1.0

# %%
bechdel.shape
# Out:
# (9373, 9)

# %% [markdown]
# ### TMDB API

# %% [markdown]
# The Movie Database (TMDB) API will help us get information from the budget and revenue to film's posters for our Streamlit app.

# %%
# Test with The Godfather (tmdb_id = 238)
movie = get_movie_details(238)
keywords = get_movie_keywords(238)

print(f"Title: {movie['title']}")
print(f"Budget: ${movie['budget']:,}")
print(f"Revenue: ${movie['revenue']:,}")
print(f"Keywords: {[k['name'] for k in keywords['keywords'][:10]]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[124], line 2
#       1 # Test with The Godfather (tmdb_id = 238)
# ----> 2 movie = get_movie_details(238)
#       3 keywords = get_movie_keywords(238)
#       5 print(f"Title: {movie['title']}")
#
# File ~/Desktop/films_project/notebooks/../src/data_collection.py:16, in get_movie_details(tmdb_id)
#      14 BASE_URL = "https://api.themoviedb.org/3"
#      15 url = f"{BASE_URL}/movie/{tmdb_id}"
# ---> 16 params = {"api_key": API_KEY}
#      17 response = requests.get(url, params=params)
#      18 return response.json()
#
# NameError: name 'API_KEY' is not defined

# %% [markdown]
# ## Cleaning the Datasets

# %% [markdown]
# ### Formatting columns names

# %% [markdown]
# First thing I want to do is standarizing column names of every dataset, so they all have the same format.

# %%
datasets = [links, movies, ratings, tags, genome_tags, genome_scores,
            name_basics, title_basics, title_crew, title_ratings,
            bechdel]
for df in datasets:
    print(df.columns)
# Out:
# Index(['movieId', 'imdbId', 'tmdbId'], dtype='object')
# Index(['movieId', 'title', 'genres'], dtype='object')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')
# Index(['tagId', 'tag'], dtype='object')
# Index(['movieId', 'tagId', 'relevance'], dtype='object')
# Index(['nconst', 'primaryName', 'birthYear', 'deathYear', 'primaryProfession',
#        'knownForTitles'],
#       dtype='object')
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres'],
#       dtype='object')
# Index(['tconst', 'directors', 'writers'], dtype='object')
# Index(['tconst', 'averageRating', 'numVotes'], dtype='object')
# Index(['title', 'year', 'rating', 'dubious', 'imdbid', 'id', 'submitterid',
#        'date', 'visible'],
#       dtype='object')

# %%
col_map = {
    'movieId' : 'movie_id',
    'imdbId' : 'imdb_id',
    'tmdbId' : 'tmdb_id',
    'title' : 'title',
    'genres' : 'genres',
    'userId' : 'user_id',
    'rating' : 'rating',
    'timestamp' : 'duration',
    'tag' : 'tag',
    'tagId' : 'tag_id',
    'relevance' : 'relevance',
    'nconst' : 'name_id',
    'primaryName' : 'name',
    'birthYear' : 'birth_year',
    'deathYear' : 'death_year',
    'primaryProfession' : 'profession',
    'knownForTitles' : 'known_for',
    'tconst' : 'imdb_id',
    'titleType' : 'title_type',
    'primaryTitle' : 'title',
    'originalTitle' : 'original_title',
    'isAdult' : 'is_adult',
    'startYear' : 'start_year',
    'endYear' : 'end_year',
    'runtimeMinutes' : 'runtime_min',
    'directors' : 'directors',
    'writers' : 'writers',
    'ordering' : 'row_per_title',
    'category' : 'category',
    'job' : 'job',
    'characters' : 'characters',
    'averageRating' : 'avg_rating',
    'numVotes' : 'num_votes',
    'year' : 'year',
    'dubious' : 'dubious',
    'imdbid' : 'imdb_id',
    'id' : 'bechdel_id',
    'submitterid' : 'user_id',
    'date' : 'submit_date',
    'visible' : 'visible',
}

def rename_columns(df, col_map = col_map):
    df.rename(mapper = col_map, axis = 1, inplace = True)
    return df

for df in datasets:
    rename_columns(df)

# %%
links.head()

#it worked :))
# Out:
#    movie_id  imdb_id  tmdb_id
# 0         1   114709    862.0
# 1         2   113497   8844.0
# 2         3   113228  15602.0
# 3         4   114885  31357.0
# 4         5   113041  11862.0

# %% [markdown]
# ### Individual cleaning of datasets

# %% [markdown]
# - We'll see what columns are useful, what to keep and what to drop.
# - We'll check datatypes and change them when needed
# - We'll format null values as now there are null values that pandas doesn't detect.
# - We'll decide what to do with them.
# - We'll handle duplicates as well.

# %% [markdown]
# #### MovieLens datasets

# %% [markdown]
# ##### Links dataset

# %%
links.head()
# Out:
#    movie_id  imdb_id  tmdb_id
# 0         1   114709    862.0
# 1         2   113497   8844.0
# 2         3   113228  15602.0
# 3         4   114885  31357.0
# 4         5   113041  11862.0

# %%
links.dtypes
# Out:
# movie_id      int64
# imdb_id       int64
# tmdb_id     float64
# dtype: object

# %%
links["imdb_id"] = "tt" + links["imdb_id"].astype(str).str.zfill(7)
# we transform the imdb_id so it has the same formatting of the imdb_ids in imdb datasets

links.head()
# Out:
#    movie_id    imdb_id  tmdb_id
# 0         1  tt0114709    862.0
# 1         2  tt0113497   8844.0
# 2         3  tt0113228  15602.0
# 3         4  tt0114885  31357.0
# 4         5  tt0113041  11862.0

# %%
links["tmdb_id"] = links["tmdb_id"].astype("Int64") 
links.head()
# Out:
#    movie_id    imdb_id  tmdb_id
# 0         1  tt0114709      862
# 1         2  tt0113497     8844
# 2         3  tt0113228    15602
# 3         4  tt0114885    31357
# 4         5  tt0113041    11862

# %%
links.dtypes
# Out:
# movie_id     int64
# imdb_id     object
# tmdb_id      Int64
# dtype: object

# %%
links.isna().sum()
# Out:
# movie_id      0
# imdb_id       0
# tmdb_id     126
# dtype: int64

# %%
links[links["tmdb_id"].isna()]
# Out:
#        movie_id    imdb_id  tmdb_id
# 706         721  tt0114103     <NA>
# 715         730  tt0125877     <NA>
# 754         770  tt0038426     <NA>
# 775         791  tt0113610     <NA>
# 1080       1107  tt0102336     <NA>
# ...         ...        ...      ...
# 69061    222211  tt7688638     <NA>
# 69755    224398  tt5868094     <NA>
# 72468    234301  tt5714216     <NA>
# 73108    237231  tt9372822     <NA>
# 84424    281988  tt8031054     <NA>
#
# [126 rows x 3 columns]

# %% [markdown]
# We'll keep the null values for the moment. We won't be able to ask the API for information abou them. However, they are a small sample, so I prefer to keep them and see if it's a problem in the future.

# %% [markdown]
# ##### Movies dataset

# %%
movies.head()
# Out:
#    movie_id                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.dtypes
# Out:
# movie_id     int64
# title       object
# genres      object
# dtype: object

# %%
# extracts year
movies['year'] = movies['title'].str.extract(r'\((\d{4})\)')

# removes year from title
movies['title'] = movies['title'].str.replace(r'\s*\(\d{4}\)', '', regex=True)

movies.head()
# Out:
#    movie_id                        title  \
# 0         1                    Toy Story
# 1         2                      Jumanji
# 2         3             Grumpier Old Men
# 3         4            Waiting to Exhale
# 4         5  Father of the Bride Part II
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
# movies['genres'] = movies['genres'].str.split('|')
# for the moment we'll keep genres as it is. as a string, but we have the option to transform it into a list if needed.

# %%
movies.isna().sum()
# Out:
# movie_id      0
# title         0
# genres        0
# year        618
# dtype: int64

# %%
movies[movies["year"].isna()]
# Out:
#        movie_id                                              title  \
# 15038     79607            Millions Game, The (Das Millionenspiel)
# 25443    123619                                 Terrible Joe Moran
# 26374    125571               The Court-Martial of Jackie Robinson
# 26399    125632                                      In Our Garden
# 26484    125958                 Stephen Fry In America - New World
# ...         ...                                                ...
# 86282    288069  American Masters: Miles Davis - Birth of the Cool
# 86365    288447                         A House A Little Too Quiet
# 86432    288661                                           Sabotage
# 86455    288725                          We Have Never Been Modern
# 86516    288927                                           Fortunes
#
#                              genres year
# 15038  Action|Drama|Sci-Fi|Thriller  NaN
# 25443            (no genres listed)  NaN
# 26374            (no genres listed)  NaN
# 26399            (no genres listed)  NaN
# 26484            (no genres listed)  NaN
# ...                             ...  ...
# 86282                   Documentary  NaN
# 86365            (no genres listed)  NaN
# 86432            (no genres listed)  NaN
# 86455                         Crime  NaN
# 86516                        Comedy  NaN
#
# [618 rows x 4 columns]

# %%
movies["genres"].value_counts()
# Out:
# genres
# Drama                                             12246
# Documentary                                        8064
# Comedy                                             7689
# (no genres listed)                                 7060
# Comedy|Drama                                       3196
#                                                   ...
# Action|Adventure|Crime|Drama|Sci-Fi                   1
# Adventure|Animation|Children|Comedy|Drama             1
# Action|Adventure|Crime|IMAX                           1
# Action|Adventure|Comedy|Crime|Mystery|Thriller        1
# Action|Adventure|Drama|Horror|Mystery|Thriller        1
# Name: count, Length: 1796, dtype: int64

# %%
movies['genres'] = movies['genres'].replace("(no genres listed)", pd.NA)

# %%
movies['genres'].isna().sum()
# Out:
# np.int64(7060)

# %% [markdown]
# ##### Ratings dataset

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating    duration
# 0        1         1     4.0  1225734739
# 1        1       110     4.0  1225865086
# 2        1       158     4.0  1225733503
# 3        1       260     4.5  1225735204
# 4        1       356     5.0  1225735119

# %%
ratings.dtypes
# Out:
# user_id       int64
# movie_id      int64
# rating      float64
# duration      int64
# dtype: object

# %%
ratings.isna().sum()
# Out:
# user_id     0
# movie_id    0
# rating      0
# duration    0
# dtype: int64

# %%
ratings.duplicated().sum()
# Out:
# np.int64(0)

# %%
# in the metadata I found that "Timestamps represent seconds since midnight Coordinated Universal Time (UTC) of January 1, 1970."
# we are dropping that column

ratings.drop(columns = ["duration"], inplace = True)
ratings.head()
# Out:
#    user_id  movie_id  rating
# 0        1         1     4.0
# 1        1       110     4.0
# 2        1       158     4.0
# 3        1       260     4.5
# 4        1       356     5.0

# %% [markdown]
# ##### Tags dataset

# %%
tags.head()
# Out:
#    user_id  movie_id            tag    duration
# 0       10       260   good vs evil  1430666558
# 1       10       260  Harrison Ford  1430666505
# 2       10       260         sci-fi  1430666538
# 3       14      1221      Al Pacino  1311600756
# 4       14      1221          mafia  1311600746

# %%
# same as before with ratings

tags.drop(columns = ["duration"], inplace = True)
tags.head()
# Out:
#    user_id  movie_id            tag
# 0       10       260   good vs evil
# 1       10       260  Harrison Ford
# 2       10       260         sci-fi
# 3       14      1221      Al Pacino
# 4       14      1221          mafia

# %%
tags.dtypes
# Out:
# user_id      int64
# movie_id     int64
# tag         object
# dtype: object

# %%
tags.isna().sum()
# Out:
# user_id      0
# movie_id     0
# tag         17
# dtype: int64

# %%
tags.dropna(inplace = True)

# this dataset may not be used in the end, but makes no sense having null values in tag when is the most important thing.

# %% [markdown]
# ##### Genome Tags dataset

# %%
genome_tags.head()
# Out:
#    tag_id           tag
# 0       1           007
# 1       2  007 (series)
# 2       3  18th century
# 3       4         1920s
# 4       5         1930s

# %%
genome_tags.dtypes
# Out:
# tag_id     int64
# tag       object
# dtype: object

# %%
genome_tags.isna().sum()
# Out:
# tag_id    0
# tag       0
# dtype: int64

# %%
genome_tags.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### Genome Score dataset

# %%
genome_scores.head()
# Out:
#    movie_id  tag_id  relevance
# 0         1       1    0.03200
# 1         1       2    0.02225
# 2         1       3    0.07000
# 3         1       4    0.05900
# 4         1       5    0.12300

# %%
genome_scores.dtypes
# Out:
# movie_id       int64
# tag_id         int64
# relevance    float64
# dtype: object

# %%
genome_scores.isna().sum()
# Out:
# movie_id     0
# tag_id       0
# relevance    0
# dtype: int64

# %%
genome_scores.duplicated().sum()
# Out:
# np.int64(0)

# %%
genome_scores[genome_scores["relevance"] > 1]
# Out:
# Empty DataFrame
# Columns: [movie_id, tag_id, relevance]
# Index: []

# %% [markdown]
# #### IMDB Datasets

# %% [markdown]
# The most important thing with the IMDB Datasets is keeping just the films that are already inside the MovieLens dataset. In order to do that, we are running the following code:

# %%
title_basics = title_basics[
    (title_basics['imdb_id'].isin(links["imdb_id"])) &  # only MovieLens films
    (title_basics['title_type'] == 'movie') &          # only films
    (title_basics['is_adult'] == 0)                  # no adult content
]

# we have filtered the one containing mostly all the info about films. we'll start cleaning that one. 
# later, we'll do the same filtering for the rest of the datasets.

# %% [markdown]
# We are going to filter all the title datasets that are the ones containing the films so that every dataset contain the required films.
#
# In all the IMDB datasets null values won't be detected by pandas as they are a string, so, we'll change that as well.  Also, genres and list of things are separated by commas, we'll standarize that using | as it was in the MovieLens one, but this will be individually.

# %%
def same_films(df):
    new_df = df[df["imdb_id"].isin(title_basics["imdb_id"])]
    return new_df

title_basics = same_films(title_basics)
title_crew = same_films(title_crew)
title_ratings = same_films(title_ratings)

imdb_data = [title_basics, title_crew, title_ratings, name_basics]

def null_values(df):
    return df.replace(to_replace="\\N", value=pd.NA, inplace=True)
    
for df in imdb_data:
    null_values(df)
# Out:
# /var/folders/w5/wcr19hyj6dbd5xldp0w0xgpc0000gn/T/ipykernel_11802/2175113721.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return df.replace(to_replace="\\N", value=pd.NA, inplace=True)

# %% [markdown]
# ##### Title Basics dataset

# %%
title_basics.head()
# Out:
#         imdb_id title_type                        title  \
# 570   tt0000574      movie  The Story of the Kelly Gang
# 2076  tt0002101      movie                    Cleopatra
# 2105  tt0002130      movie              Dante's Inferno
# 2396  tt0002423      movie                      Passion
# 2418  tt0002445      movie                   Quo Vadis?
#
#                    original_title  is_adult start_year end_year runtime_min  \
# 570   The Story of the Kelly Gang         0       1906     <NA>          70
# 2076                    Cleopatra         0       1912     <NA>         100
# 2105                    L'inferno         0       1911     <NA>          71
# 2396               Madame DuBarry         0       1919     <NA>         113
# 2418                   Quo Vadis?         0       1913     <NA>         120
#
#                           genres
# 570   Action,Adventure,Biography
# 2076               Drama,History
# 2105     Adventure,Drama,Fantasy
# 2396     Biography,Drama,Romance
# 2418               Drama,History

# %%
title_basics["genres"] = title_basics["genres"].str.replace(",", "|")
title_basics.head()
# Out:
#         imdb_id title_type                        title  \
# 570   tt0000574      movie  The Story of the Kelly Gang
# 2076  tt0002101      movie                    Cleopatra
# 2105  tt0002130      movie              Dante's Inferno
# 2396  tt0002423      movie                      Passion
# 2418  tt0002445      movie                   Quo Vadis?
#
#                    original_title  is_adult start_year end_year runtime_min  \
# 570   The Story of the Kelly Gang         0       1906     <NA>          70
# 2076                    Cleopatra         0       1912     <NA>         100
# 2105                    L'inferno         0       1911     <NA>          71
# 2396               Madame DuBarry         0       1919     <NA>         113
# 2418                   Quo Vadis?         0       1913     <NA>         120
#
#                           genres
# 570   Action|Adventure|Biography
# 2076               Drama|History
# 2105     Adventure|Drama|Fantasy
# 2396     Biography|Drama|Romance
# 2418               Drama|History

# %%
title_basics.dtypes
# Out:
# imdb_id           object
# title_type        object
# title             object
# original_title    object
# is_adult           int64
# start_year        object
# end_year          object
# runtime_min       object
# genres            object
# dtype: object

# %%
title_basics.isna().sum()

# the start year may be completed with the movielens dataset
# we'll keep the null values in the runtime as well. 
# 70 genres won't be that important with the amount of data we have already. I prefer to keep them anyway.
# Out:
# imdb_id               0
# title_type            0
# title                 0
# original_title        0
# is_adult              0
# start_year           12
# end_year          70545
# runtime_min         187
# genres               70
# dtype: int64

# %%
title_basics.drop(columns = ["end_year"], inplace = True) # this column only makes sense for tvshows
title_basics.drop(columns = ["original_title"], inplace = True) # I prefer to keep the famous name only
title_basics.drop(columns = ["title_type"], inplace = True) # Once we have filter by movies it makes no sense to keep this
title_basics.drop(columns = ["is_adult"], inplace = True) # Once we have filter this it makes no sense to keep this

# %%
title_basics[["start_year", "runtime_min"]] = title_basics[["start_year", "runtime_min"]].astype("Int64")

# %%
title_basics.head()
# Out:
#         imdb_id                        title  start_year  runtime_min  \
# 570   tt0000574  The Story of the Kelly Gang        1906           70
# 2076  tt0002101                    Cleopatra        1912          100
# 2105  tt0002130              Dante's Inferno        1911           71
# 2396  tt0002423                      Passion        1919          113
# 2418  tt0002445                   Quo Vadis?        1913          120
#
#                           genres
# 570   Action|Adventure|Biography
# 2076               Drama|History
# 2105     Adventure|Drama|Fantasy
# 2396     Biography|Drama|Romance
# 2418               Drama|History

# %% [markdown]
# ##### Name Basics dataset

# %%
name_basics.head()
# Out:
#      name_id             name birth_year death_year  \
# 0  nm0000001     Fred Astaire       1899       1987
# 1  nm0000002    Lauren Bacall       1924       2014
# 2  nm0000003  Brigitte Bardot       1934       2025
# 3  nm0000004     John Belushi       1949       1982
# 4  nm0000005   Ingmar Bergman       1918       2007
#
#                           profession                                known_for
# 0       actor,miscellaneous,producer  tt0072308,tt0050419,tt0027125,tt0025164
# 1   actress,miscellaneous,soundtrack  tt0037382,tt0075213,tt0038355,tt0045891
# 2  actress,music_department,producer  tt0057345,tt0049189,tt0056404,tt0054452
# 3      actor,writer,music_department  tt0072562,tt0077975,tt0080455,tt0078723
# 4              writer,director,actor  tt0050986,tt0069467,tt0050976,tt0083922

# %%
name_basics["profession"] = name_basics["profession"].str.replace(",", "|")
name_basics["known_for"] = name_basics["known_for"].str.replace(",", "|")
name_basics.head()
# Out:
#      name_id             name birth_year death_year  \
# 0  nm0000001     Fred Astaire       1899       1987
# 1  nm0000002    Lauren Bacall       1924       2014
# 2  nm0000003  Brigitte Bardot       1934       2025
# 3  nm0000004     John Belushi       1949       1982
# 4  nm0000005   Ingmar Bergman       1918       2007
#
#                           profession                                known_for
# 0       actor|miscellaneous|producer  tt0072308|tt0050419|tt0027125|tt0025164
# 1   actress|miscellaneous|soundtrack  tt0037382|tt0075213|tt0038355|tt0045891
# 2  actress|music_department|producer  tt0057345|tt0049189|tt0056404|tt0054452
# 3      actor|writer|music_department  tt0072562|tt0077975|tt0080455|tt0078723
# 4              writer|director|actor  tt0050986|tt0069467|tt0050976|tt0083922

# %%
name_basics.dtypes
# Out:
# name_id       object
# name          object
# birth_year    object
# death_year    object
# profession    object
# known_for     object
# dtype: object

# %%
name_basics.isna().sum()

# we can keep profession and know for for the moment. we'll decide when doing the analysis.
# Out:
# name_id              0
# name                78
# birth_year    14663276
# death_year    15077629
# profession     3087867
# known_for      1835554
# dtype: int64

# %%
name_basics.shape
# Out:
# (15336275, 6)

# %%
name_basics.drop(columns = ["birth_year", "death_year"], inplace = True) #useless for us and lot's of null values

# %%
name_basics["name"].dropna(inplace = True) # does it make sense to keep them if we don't know their names?

# %%
name_basics.head()
# Out:
#      name_id             name                         profession  \
# 0  nm0000001     Fred Astaire       actor|miscellaneous|producer
# 1  nm0000002    Lauren Bacall   actress|miscellaneous|soundtrack
# 2  nm0000003  Brigitte Bardot  actress|music_department|producer
# 3  nm0000004     John Belushi      actor|writer|music_department
# 4  nm0000005   Ingmar Bergman              writer|director|actor
#
#                                  known_for
# 0  tt0072308|tt0050419|tt0027125|tt0025164
# 1  tt0037382|tt0075213|tt0038355|tt0045891
# 2  tt0057345|tt0049189|tt0056404|tt0054452
# 3  tt0072562|tt0077975|tt0080455|tt0078723
# 4  tt0050986|tt0069467|tt0050976|tt0083922

# %% [markdown]
# ##### Title Crew dataset

# %%
title_crew.head()
# Out:
#         imdb_id                      directors              writers
# 570   tt0000574                      nm0846879            nm0846879
# 2076  tt0002101                      nm0309130  nm0765026,nm0309130
# 2105  tt0002130  nm0078205,nm0655824,nm0209738            nm0019604
# 2396  tt0002423                      nm0523932  nm0266183,nm0473134
# 2418  tt0002445                      nm0345500  nm0797197,nm0345500

# %%
title_crew.isna().sum()
# Out:
# imdb_id         0
# directors      76
# writers      3171
# dtype: int64

# %%
# i'm dropping the writers as I'm not interested in them.
# i'm keeping null values in directors

title_crew.drop(columns = "writers", inplace = True)
# Out:
# /var/folders/w5/wcr19hyj6dbd5xldp0w0xgpc0000gn/T/ipykernel_11802/3431090814.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   title_crew.drop(columns = "writers", inplace = True)

# %% [markdown]
# ##### Title Ratings dataset

# %%
title_ratings.head()
# Out:
#         imdb_id  avg_rating  num_votes
# 545   tt0000574         6.0       1069
# 1269  tt0002101         5.1        675
# 1277  tt0002130         7.1       4125
# 1385  tt0002423         6.7       1130
# 1393  tt0002445         6.1        536

# %%
title_ratings.dtypes
# Out:
# imdb_id        object
# avg_rating    float64
# num_votes       int64
# dtype: object

# %%
title_ratings.isna().sum()
# Out:
# imdb_id       0
# avg_rating    0
# num_votes     0
# dtype: int64

# %% [markdown]
# #### Bechdel dataset

# %%
bechdel.head()
# Out:
#                         title    year  rating  dubious     imdb_id  \
# 0            Passage de Venus  1874.0     0.0      0.0   3155794.0
# 1           La Rosace Magique  1877.0     0.0      0.0  14495706.0
# 2  Sallie Gardner at a Gallop  1878.0     0.0      0.0   2221420.0
# 3           Le singe musicien  1878.0     0.0      0.0  12592084.0
# 4     Athlete Swinging a Pick  1881.0     0.0      0.0   7816420.0
#
#    bechdel_id  user_id          submit_date  visible
# 0      9602.0  18880.0  2021-04-02 20:58:09      1.0
# 1      9804.0  19145.0  2021-05-11 00:11:22      1.0
# 2      9603.0  18882.0  2021-04-03 02:25:27      1.0
# 3      9806.0  19151.0  2021-05-11 23:38:54      1.0
# 4      9816.0  19162.0  2021-05-13 01:32:14      1.0

# %%
bechdel['imdb_id'] = bechdel['imdb_id'].astype('Int64').astype(str)
bechdel["imdb_id"] = "tt" + bechdel["imdb_id"].astype(str).str.zfill(7)
bechdel.head()
# Out:
#                         title    year  rating  dubious     imdb_id  \
# 0            Passage de Venus  1874.0     0.0      0.0   tt3155794
# 1           La Rosace Magique  1877.0     0.0      0.0  tt14495706
# 2  Sallie Gardner at a Gallop  1878.0     0.0      0.0   tt2221420
# 3           Le singe musicien  1878.0     0.0      0.0  tt12592084
# 4     Athlete Swinging a Pick  1881.0     0.0      0.0   tt7816420
#
#    bechdel_id  user_id          submit_date  visible
# 0      9602.0  18880.0  2021-04-02 20:58:09      1.0
# 1      9804.0  19145.0  2021-05-11 00:11:22      1.0
# 2      9603.0  18882.0  2021-04-03 02:25:27      1.0
# 3      9806.0  19151.0  2021-05-11 23:38:54      1.0
# 4      9816.0  19162.0  2021-05-13 01:32:14      1.0

# %%
bechdel = same_films(bechdel)
bechdel
# even though this is one of our most important datasets and it is also one of the smaller, we need to drop some rows as we need to have films that are already on our other two datasets.
# Out:
#                              title    year  rating  dubious     imdb_id  \
# 116   Story of the Kelly Gang, The  1906.0     1.0      0.0   tt0000574
# 132                      Cleopatra  1912.0     2.0      0.0   tt0002101
# 137          A Florida Enchantment  1914.0     2.0      1.0   tt0003973
# 138         Birth of a Nation, The  1915.0     2.0      0.0   tt0004972
# 139         Gretchen the Greenhorn  1916.0     3.0      0.0   tt0006745
# ...                            ...     ...     ...      ...         ...
# 9367                       Encanto  2021.0     3.0      0.0   tt2953050
# 9368                     Love Hard  2021.0     2.0      0.0  tt10752004
# 9369                       Cruella  2021.0     3.0      0.0   tt3228774
# 9370               West Side Story  2021.0     3.0      0.0   tt3581652
# 9372            Single All The Way  2021.0     3.0      0.0  tt14315756
#
#       bechdel_id  user_id          submit_date  visible
# 116       1349.0   1469.0  2010-07-26 21:01:14      1.0
# 132       2003.0   2676.0  2011-02-07 06:12:54      1.0
# 137       4457.0   7991.0  2013-08-10 05:01:03      1.0
# 138       1258.0   1359.0  2010-07-23 00:46:01      1.0
# 139       2008.0   2685.0  2011-02-08 06:49:30      1.0
# ...          ...      ...                  ...      ...
# 9367     10151.0  19732.0  2021-12-02 00:36:48      1.0
# 9368     10152.0  19735.0  2021-12-05 19:22:20      1.0
# 9369      9861.0  19231.0  2021-06-01 03:16:58      1.0
# 9370     10157.0  19743.0  2021-12-10 03:10:09      1.0
# 9372     10161.0  19753.0  2021-12-15 10:10:36      1.0
#
# [8200 rows x 9 columns]

# %%
bechdel.drop(columns = ["bechdel_id", "user_id", "submit_date"], inplace = True) # we don't need more ids and we don't need the submit date either
bechdel.drop(columns = ["title", "year"], inplace = True) # we already have these data in other datasets
bechdel.drop(columns = ["visible"], inplace = True) # doesn't give information
# Out:
# /var/folders/w5/wcr19hyj6dbd5xldp0w0xgpc0000gn/T/ipykernel_11802/60342363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bechdel.drop(columns = ["bechdel_id", "user_id", "submit_date"], inplace = True) # we don't need more ids and we don't need the submit date either
# /var/folders/w5/wcr19hyj6dbd5xldp0w0xgpc0000gn/T/ipykernel_11802/60342363.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bechdel.drop(columns = ["title", "year"], inplace = True) # we already have these data in other datasets
# /var/folders/w5/wcr19hyj6dbd5xldp0w0xgpc0000gn/T/ipykernel_11802/60342363.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bechdel.drop(columns = ["visible"], inplace = True) # doesn't give information

# %%
bechdel = bechdel[["imdb_id", "rating", "dubious"]]
bechdel.head()
# Out:
#        imdb_id  rating  dubious
# 116  tt0000574     1.0      0.0
# 132  tt0002101     2.0      0.0
# 137  tt0003973     2.0      1.0
# 138  tt0004972     2.0      0.0
# 139  tt0006745     3.0      0.0

# %%
print(bechdel["rating"].value_counts())
print("\n")
print(bechdel["dubious"].value_counts())
# Out:
# rating
# 3.0    4652
# 1.0    1877
# 2.0     869
# 0.0     802
# Name: count, dtype: int64
#
#
# dubious
# 0.0    7179
# 1.0     734
# Name: count, dtype: int64

# %%
bechdel[bechdel["dubious"] == 1]["rating"].value_counts()
# I was thinking on dropping dubious. I don't know if it'll be useful so I'll keep it, for the moment.
# Out:
# rating
# 3.0    545
# 2.0    102
# 1.0     67
# 0.0     20
# Name: count, dtype: int64

# %% [markdown]
# #### MovieLens datasets

# %% [markdown]
# We did the filtering in the IMDB datasets with MovieLens as the base. However, we did use some filter after that (the is_adult and the title_type), so there is still a difference in rows and films between datasets.

# %%
links = same_films(links)
links.head()
# Out:
#    movie_id    imdb_id  tmdb_id
# 0         1  tt0114709      862
# 1         2  tt0113497     8844
# 2         3  tt0113228    15602
# 3         4  tt0114885    31357
# 4         5  tt0113041    11862

# %%
links.shape
# Out:
# (70545, 3)

# %% [markdown]
# now do the same but with the movie lens datasets using movieid
